# %% [markdown]
# # Intro

# %% [markdown]
# ## Links

# %% [markdown]
# Canvas: https://canvas.northwestern.edu/courses/167719/assignments/1078610?module_item_id=2319284

# %% [markdown]
# Kaggle: https://www.kaggle.com/c/dogs-vs-cats-redux-kernels-edition

# %% [markdown]
# ## Modules

# %%
#For data manipulation and visualization
from google.colab import files

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
from matplotlib.pyplot import subplots_adjust
import seaborn as sns
import random


from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.decomposition import PCA
from sklearn.metrics import accuracy_score, f1_score, classification_report, confusion_matrix, precision_score, recall_score, precision_recall_curve
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import MiniBatchKMeans
from sklearn import cluster

from datetime import datetime

from os import makedirs
from os import listdir
from shutil import copyfile
from random import seed
from random import random

import tensorflow as tf
import keras

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img
from keras import backend as K


import os, cv2, re, random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image

import pathlib

# Disable warning
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Data Ingestion

# %% [markdown]
# ## Kaggle Upload

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))

# Then move kaggle.json into the folder where the API expects to find it.
# !mkdir -p ~/.kaggle/ && mv kaggle.json ~/.kaggle/ && chmod 600 ~/.kaggle/kaggle.json
# Out:
#      <input type="file" id="files-0e86789d-695e-42a9-9da1-9f0cee66f995" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0e86789d-695e-42a9-9da1-9f0cee66f995">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# User uploaded file "kaggle.json" with length 63 bytes

# %%
# %%capture
# !kaggle competitions download -c dogs-vs-cats-redux-kernels-edition

# %% [markdown]
# ## Kaggle Data Prep

# %%
# !unzip 'dogs-vs-cats-redux-kernels-edition.zip'
# Out:
# Archive:  dogs-vs-cats-redux-kernels-edition.zip
#   inflating: sample_submission.csv
#   inflating: test.zip
#   inflating: train.zip

# %%
# !unzip /content/train.zip
# !unzip /content/test.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: test/5499.jpg
#   inflating: test/55.jpg
#   inflating: test/550.jpg
#   inflating: test/5500.jpg
#   inflating: test/5501.jpg
#   inflating: test/5502.jpg
#   inflating: test/5503.jpg
#   inflating: test/5504.jpg
#   inflating: test/5505.jpg
#   inflating: test/5506.jpg
#   inflating: test/5507.jpg
#   inflating: test/5508.jpg
#   inflating: test/5509.jpg
#   inflating: test/551.jpg
#   inflating: test/5510.jpg
#   inflating: test/5511.jpg
#   inflating: test/5512.jpg
#   inflating: test/5513.jpg
#   inflating: test/5514.jpg
#   inflating: test/5515.jpg
#   inflating: test/5516.jpg
#   inflating: test/5517.jpg
#   inflating: test/5518.jpg
#   inflating: test/5519.jpg
#   inflating: test/552.jpg
#   inflating: test/5520.jpg
#   inflating: test/5521.jpg
#   inflating: test/5522.jpg
#   inflating: test/5523.jpg
#   inflating: test/5524.jpg
#   inflating: test/5525.jpg
#   inflating: test/5526.jpg
#   inflating: test/5527.jpg
#   inflating: test/5528.jpg
#   inflating: test/5529.jpg
#   inflating: test/553.jpg
#   inflating: test/5530.jpg
#   inflating: test/5531.jpg
#   inflating: test/5532.jpg
#   inflating: test/5533.jpg
#   inflating: test/5534.jpg
#   inflating: test/5535.jpg
#   inflating: test/5536.jpg
#   inflating: test/5537.jpg
#   inflating: test/5538.jpg
#   inflating: test/5539.jpg
#   inflating: test/554.jpg
#   inflating: test/5540.jpg
#   inflating: test/5541.jpg
#   inflating: test/5542.jpg
#   inflating: test/5543.jpg
#   inflating: test/5544.jpg
#   inflating: test/5545.jpg
#   inflating: test/5546.jpg
#   inflating: test/5547.jpg
#   inflating: test/5548.jpg
#   inflating: test/5549.jpg
#   inflating: test/555.jpg
#   inflating: test/5550.jpg
#   inflating: test/5551.jpg
#   inflating: test/5552.jpg
#   inflating: test/5553.jpg
#   inflating: test/5554.jpg
#   inflating: test/5555.jpg
#   inflating: test/5556.jpg
#   inflating: test/5557.jpg
#   inflating: test/5558.jpg
#   inflating: test/5559.jpg
#   inflating: test/556.jpg
#   inflating: test/5560.jpg
#   inflating: test/5561.jpg
#   inflating: test/5562.jpg
#   inflating: test/5563.jpg
#   inflating: test/5564.jpg
#   inflating: test/5565.jpg
#   inflating: test/5566.jpg
#   inflating: test/5567.jpg
#   inflating: test/5568.jpg
#   inflating: test/5569.jpg
#   inflating: test/557.jpg
#   inflating: test/5570.jpg
#   inflating: test/5571.jpg
#   inflating: test/5572.jpg
#   inflating: test/5573.jpg
#   inflating: test/5574.jpg
#   inflating: test/5575.jpg
#   inflating: test/5576.jpg
#   inflating: test/5577.jpg
#   inflating: test/5578.jpg
#   inflating: test/5579.jpg
#   inflating: test/558.jpg
#   inflating: test/5580.jpg
#   inflating: test/5581.jpg
#   inflating: test/5582.jpg
#   inflating: test/5583.jpg
#   inflating: test/5584.jpg
#   inflating: test/5585.jpg
#   inflating: test/5586.jpg
#   inflating: test/5587.jpg
#   inflating: test/5588.jpg
#   inflating: test/5589.jpg
#   inflating: test/559.jpg
#   inflating: test/5590.jpg
#   inflating: test/5591.jpg
#   inflating: test/5592.jpg
#   inflating: test/5593.jpg
#   inflating: test/5594.jpg
#   inflating: test/5595.jpg
#   inflating: test/5596.jpg
#   inflating: test/5597.jpg
#   inflating: test/5598.jpg
#   inflating: test/5599.jpg
#   inflating: test/56.jpg
#   inflating: test/560.jpg
#   inflating: test/5600.jpg
#   inflating: test/5601.jpg
#   inflating: test/5602.jpg
#   inflating: test/5603.jpg
#   inflating: test/5604.jpg
#   inflating: test/5605.jpg
#   inflating: test/5606.jpg
#   inflating: test/5607.jpg
#   inflating: test/5608.jpg
#   inflating: test/5609.jpg
#   inflating: test/561.jpg
#   inflating: test/5610.jpg
#   inflating: test/5611.jpg
#   inflating: test/5612.jpg
#   inflating: test/5613.jpg
#   inflating: test/5614.jpg
#   inflating: test/5615.jpg
#   inflating: test/5616.jpg
#   inflating: test/5617.jpg
#   inflating: test/5618.jpg
#   inflating: test/5619.jpg
#   inflating: test/562.jpg
#   inflating: test/5620.jpg
#   inflating: test/5621.jpg
#   inflating: test/5622.jpg
#   inflating: test/5623.jpg
#   inflating: test/5624.jpg
#   inflating: test/5625.jpg
#   inflating: test/5626.jpg
#   inflating: test/5627.jpg
#   inflating: test/5628.jpg
#   inflating: test/5629.jpg
#   inflating: test/563.jpg
#   inflating: test/5630.jpg
#   inflating: test/5631.jpg
#   inflating: test/5632.jpg
#   inflating: test/5633.jpg
#   inflating: test/5634.jpg
#   inflating: test/5635.jpg
#   inflating: test/5636.jpg
#   inflating: test/5637.jpg
#   inflating: test/5638.jpg
#   inflating: test/5639.jpg
#   inflating: test/564.jpg
#   inflating: test/5640.jpg
#   inflating: test/5641.jpg
#   inflating: test/5642.jpg
#   inflating: test/5643.jpg
#   inflating: test/5644.jpg
#   inflating: test/5645.jpg
#   inflating: test/5646.jpg
#   inflating: test/5647.jpg
#   inflating: test/5648.jpg
#   inflating: test/5649.jpg
#   inflating: test/565.jpg
#   inflating: test/5650.jpg
#   inflating: test/5651.jpg
#   inflating: test/5652.jpg
#   inflating: test/5653.jpg
#   inflating: test/5654.jpg
#   inflating: test/5655.jpg
#   inflating: test/5656.jpg
#   inflating: test/5657.jpg
#   inflating: test/5658.jpg
#   inflating: test/5659.jpg
#   inflating: test/566.jpg
#   inflating: test/5660.jpg
#   inflating: test/5661.jpg
#   inflating: test/5662.jpg
#   inflating: test/5663.jpg
#   inflating: test/5664.jpg
#   inflating: test/5665.jpg
#   inflating: test/5666.jpg
#   inflating: test/5667.jpg
#   inflating: test/5668.jpg
#   inflating: test/5669.jpg
#   inflating: test/567.jpg
#   inflating: test/5670.jpg
#   inflating: test/5671.jpg
#   inflating: test/5672.jpg
#   inflating: test/5673.jpg
#   inflating: test/5674.jpg
#   inflating: test/5675.jpg
#   inflating: test/5676.jpg
#   inflating: test/5677.jpg
#   inflating: test/5678.jpg
#   inflating: test/5679.jpg
#   inflating: test/568.jpg
#   inflating: test/5680.jpg
#   inflating: test/5681.jpg
#   inflating: test/5682.jpg
#   inflating: test/5683.jpg
#   inflating: test/5684.jpg
#   inflating: test/5685.jpg
#   inflating: test/5686.jpg
#   inflating: test/5687.jpg
#   inflating: test/5688.jpg
#   inflating: test/5689.jpg
#   inflating: test/569.jpg
#   inflating: test/5690.jpg
#   inflating: test/5691.jpg
#   inflating: test/5692.jpg
#   inflating: test/5693.jpg
#   inflating: test/5694.jpg
#   inflating: test/5695.jpg
#   inflating: test/5696.jpg
#   inflating: test/5697.jpg
#   inflating: test/5698.jpg
#   inflating: test/5699.jpg
#   inflating: test/57.jpg
#   inflating: test/570.jpg
#   inflating: test/5700.jpg
#   inflating: test/5701.jpg
#   inflating: test/5702.jpg
#   inflating: test/5703.jpg
#   inflating: test/5704.jpg
#   inflating: test/5705.jpg
#   inflating: test/5706.jpg
#   inflating: test/5707.jpg
#   inflating: test/5708.jpg
#   inflating: test/5709.jpg
#   inflating: test/571.jpg
#   inflating: test/5710.jpg
#   inflating: test/5711.jpg
#   inflating: test/5712.jpg
#   inflating: test/5713.jpg
#   inflating: test/5714.jpg
#   inflating: test/5715.jpg
#   inflating: test/5716.jpg
#   inflating: test/5717.jpg
#   inflating: test/5718.jpg
#   inflating: test/5719.jpg
#   inflating: test/572.jpg
#   inflating: test/5720.jpg
#   inflating: test/5721.jpg
#   inflating: test/5722.jpg
#   inflating: test/5723.jpg
#   inflating: test/5724.jpg
#   inflating: test/5725.jpg
#   inflating: test/5726.jpg
#   inflating: test/5727.jpg
#   inflating: test/5728.jpg
#   inflating: test/5729.jpg
#   inflating: test/573.jpg
#   inflating: test/5730.jpg
#   inflating: test/5731.jpg
#   inflating: test/5732.jpg
#   inflating: test/5733.jpg
#   inflating: test/5734.jpg
#   inflating: test/5735.jpg
#   inflating: test/5736.jpg
#   inflating: test/5737.jpg
#   inflating: test/5738.jpg
#   inflating: test/5739.jpg
#   inflating: test/574.jpg
#   inflating: test/5740.jpg
#   inflating: test/5741.jpg
#   inflating: test/5742.jpg
#   inflating: test/5743.jpg
#   inflating: test/5744.jpg
#   inflating: test/5745.jpg
#   inflating: test/5746.jpg
#   inflating: test/5747.jpg
#   inflating: test/5748.jpg
#   inflating: test/5749.jpg
#   inflating: test/575.jpg
#   inflating: test/5750.jpg
#   inflating: test/5751.jpg
#   inflating: test/5752.jpg
#   inflating: test/5753.jpg
#   inflating: test/5754.jpg
#   inflating: test/5755.jpg
#   inflating: test/5756.jpg
#   inflating: test/5757.jpg
#   inflating: test/5758.jpg
#   inflating: test/5759.jpg
#   inflating: test/576.jpg
#   inflating: test/5760.jpg
#   inflating: test/5761.jpg
#   inflating: test/5762.jpg
#   inflating: test/5763.jpg
#   inflating: test/5764.jpg
#   inflating: test/5765.jpg
#   inflating: test/5766.jpg
#   inflating: test/5767.jpg
#   inflating: test/5768.jpg
#   inflating: test/5769.jpg
#   inflating: test/577.jpg
#   inflating: test/5770.jpg
#   inflating: test/5771.jpg
#   inflating: test/5772.jpg
#   inflating: test/5773.jpg
#   inflating: test/5774.jpg
#   inflating: test/5775.jpg
#   inflating: test/5776.jpg
#   inflating: test/5777.jpg
#   inflating: test/5778.jpg
#   inflating: test/5779.jpg
#   inflating: test/578.jpg
#   inflating: test/5780.jpg
#   inflating: test/5781.jpg
#   inflating: test/5782.jpg
#   inflating: test/5783.jpg
#   inflating: test/5784.jpg
#   inflating: test/5785.jpg
#   inflating: test/5786.jpg
#   inflating: test/5787.jpg
#   inflating: test/5788.jpg
#   inflating: test/5789.jpg
#   inflating: test/579.jpg
#   inflating: test/5790.jpg
#   inflating: test/5791.jpg
#   inflating: test/5792.jpg
#   inflating: test/5793.jpg
#   inflating: test/5794.jpg
#   inflating: test/5795.jpg
#   inflating: test/5796.jpg
#   inflating: test/5797.jpg
#   inflating: test/5798.jpg
#   inflating: test/5799.jpg
#   inflating: test/58.jpg
#   inflating: test/580.jpg
#   inflating: test/5800.jpg
#   inflating: test/5801.jpg
#   inflating: test/5802.jpg
#   inflating: test/5803.jpg
#   inflating: test/5804.jpg
#   inflating: test/5805.jpg
#   inflating: test/5806.jpg
#   inflating: test/5807.jpg
#   inflating: test/5808.jpg
#   inflating: test/5809.jpg
#   inflating: test/581.jpg
#   inflating: test/5810.jpg
#   inflating: test/5811.jpg
#   inflating: test/5812.jpg
#   inflating: test/5813.jpg
#   inflating: test/5814.jpg
#   inflating: test/5815.jpg
#   inflating: test/5816.jpg
#   inflating: test/5817.jpg
#   inflating: test/5818.jpg
#   inflating: test/5819.jpg
#   inflating: test/582.jpg
#   inflating: test/5820.jpg
#   inflating: test/5821.jpg
#   inflating: test/5822.jpg
#   inflating: test/5823.jpg
#   inflating: test/5824.jpg
#   inflating: test/5825.jpg
#   inflating: test/5826.jpg
#   inflating: test/5827.jpg
#   inflating: test/5828.jpg
#   inflating: test/5829.jpg
#   inflating: test/583.jpg
#   inflating: test/5830.jpg
#   inflating: test/5831.jpg
#   inflating: test/5832.jpg
#   inflating: test/5833.jpg
#   inflating: test/5834.jpg
#   inflating: test/5835.jpg
#   inflating: test/5836.jpg
#   inflating: test/5837.jpg
#   inflating: test/5838.jpg
#   inflating: test/5839.jpg
#   inflating: test/584.jpg
#   inflating: test/5840.jpg
#   inflating: test/5841.jpg
#   inflating: test/5842.jpg
#   inflating: test/5843.jpg
#   inflating: test/5844.jpg
#   inflating: test/5845.jpg
#   inflating: test/5846.jpg
#   inflating: test/5847.jpg
#   inflating: test/5848.jpg
#   inflating: test/5849.jpg
#   inflating: test/585.jpg
#   inflating: test/5850.jpg
#   inflating: test/5851.jpg
#   inflating: test/5852.jpg
#   inflating: test/5853.jpg
#   inflating: test/5854.jpg
#   inflating: test/5855.jpg
#   inflating: test/5856.jpg
#   inflating: test/5857.jpg
#   inflating: test/5858.jpg
#   inflating: test/5859.jpg
#   inflating: test/586.jpg
#   inflating: test/5860.jpg
#   inflating: test/5861.jpg
#   inflating: test/5862.jpg
#   inflating: test/5863.jpg
#   inflating: test/5864.jpg
#   inflating: test/5865.jpg
#   inflating: test/5866.jpg
#   inflating: test/5867.jpg
#   inflating: test/5868.jpg
#   inflating: test/5869.jpg
#   inflating: test/587.jpg
#   inflating: test/5870.jpg
#   inflating: test/5871.jpg
#   inflating: test/5872.jpg
#   inflating: test/5873.jpg
#   inflating: test/5874.jpg
#   inflating: test/5875.jpg
#   inflating: test/5876.jpg
#   inflating: test/5877.jpg
#   inflating: test/5878.jpg
#   inflating: test/5879.jpg
#   inflating: test/588.jpg
#   inflating: test/5880.jpg
#   inflating: test/5881.jpg
#   inflating: test/5882.jpg
#   inflating: test/5883.jpg
#   inflating: test/5884.jpg
#   inflating: test/5885.jpg
#   inflating: test/5886.jpg
#   inflating: test/5887.jpg
#   inflating: test/5888.jpg
#   inflating: test/5889.jpg
#   inflating: test/589.jpg
#   inflating: test/5890.jpg
#   inflating: test/5891.jpg
#   inflating: test/5892.jpg
#   inflating: test/5893.jpg
#   inflating: test/5894.jpg
#   inflating: test/5895.jpg
#   inflating: test/5896.jpg
#   inflating: test/5897.jpg
#   inflating: test/5898.jpg
#   inflating: test/5899.jpg
#   inflating: test/59.jpg
#   inflating: test/590.jpg
#   inflating: test/5900.jpg
#   inflating: test/5901.jpg
#   inflating: test/5902.jpg
#   inflating: test/5903.jpg
#   inflating: test/5904.jpg
#   inflating: test/5905.jpg
#   inflating: test/5906.jpg
#   inflating: test/5907.jpg
#   inflating: test/5908.jpg
#   inflating: test/5909.jpg
#   inflating: test/591.jpg
#   inflating: test/5910.jpg
#   inflating: test/5911.jpg
#   inflating: test/5912.jpg
#   inflating: test/5913.jpg
#   inflating: test/5914.jpg
#   inflating: test/5915.jpg
#   inflating: test/5916.jpg
#   inflating: test/5917.jpg
#   inflating: test/5918.jpg
#   inflating: test/5919.jpg
#   inflating: test/592.jpg
#   inflating: test/5920.jpg
#   inflating: test/5921.jpg
#   inflating: test/5922.jpg
#   inflating: test/5923.jpg
#   inflating: test/5924.jpg
#   inflating: test/5925.jpg
#   inflating: test/5926.jpg
#   inflating: test/5927.jpg
#   inflating: test/5928.jpg
#   inflating: test/5929.jpg
#   inflating: test/593.jpg
#   inflating: test/5930.jpg
#   inflating: test/5931.jpg
#   inflating: test/5932.jpg
#   inflating: test/5933.jpg
#   inflating: test/5934.jpg
#   inflating: test/5935.jpg
#   inflating: test/5936.jpg
#   inflating: test/5937.jpg
#   inflating: test/5938.jpg
#   inflating: test/5939.jpg
#   inflating: test/594.jpg
#   inflating: test/5940.jpg
#   inflating: test/5941.jpg
#   inflating: test/5942.jpg
#   inflating: test/5943.jpg
#   inflating: test/5944.jpg
#   inflating: test/5945.jpg
#   inflating: test/5946.jpg
#   inflating: test/5947.jpg
#   inflating: test/5948.jpg
#   inflating: test/5949.jpg
#   inflating: test/595.jpg
#   inflating: test/5950.jpg
#   inflating: test/5951.jpg
#   inflating: test/5952.jpg
#   inflating: test/5953.jpg
#   inflating: test/5954.jpg
#   inflating: test/5955.jpg
#   inflating: test/5956.jpg
#   inflating: test/5957.jpg
#   inflating: test/5958.jpg
#   inflating: test/5959.jpg
#   inflating: test/596.jpg
#   inflating: test/5960.jpg
#   inflating: test/5961.jpg
#   inflating: test/5962.jpg
#   inflating: test/5963.jpg
#   inflating: test/5964.jpg
#   inflating: test/5965.jpg
#   inflating: test/5966.jpg
#   inflating: test/5967.jpg
#   inflating: test/5968.jpg
#   inflating: test/5969.jpg
#   inflating: test/597.jpg
#   inflating: test/5970.jpg
#   inflating: test/5971.jpg
#   inflating: test/5972.jpg
#   inflating: test/5973.jpg
#   inflating: test/5974.jpg
#   inflating: test/5975.jpg
#   inflating: test/5976.jpg
#   inflating: test/5977.jpg
#   inflating: test/5978.jpg
#   inflating: test/5979.jpg
#   inflating: test/598.jpg
#   inflating: test/5980.jpg
#   inflating: test/5981.jpg
#   inflating: test/5982.jpg
#   inflating: test/5983.jpg
#   inflating: test/5984.jpg
#   inflating: test/5985.jpg
#   inflating: test/5986.jpg
#   inflating: test/5987.jpg
#   inflating: test/5988.jpg
#   inflating: test/5989.jpg
#   inflating: test/599.jpg
#   inflating: test/5990.jpg
#   inflating: test/5991.jpg
#   inflating: test/5992.jpg
#   inflating: test/5993.jpg
#   inflating: test/5994.jpg
#   inflating: test/5995.jpg
#   inflating: test/5996.jpg
#   inflating: test/5997.jpg
#   inflating: test/5998.jpg
#   inflating: test/5999.jpg
#   inflating: test/6.jpg
#   inflating: test/60.jpg
#   inflating: test/600.jpg
#   inflating: test/6000.jpg
#   inflating: test/6001.jpg
#   inflating: test/6002.jpg
#   inflating: test/6003.jpg
#   inflating: test/6004.jpg
#   inflating: test/6005.jpg
#   inflating: test/6006.jpg
#   inflating: test/6007.jpg
#   inflating: test/6008.jpg
#   inflating: test/6009.jpg
#   inflating: test/601.jpg
#   inflating: test/6010.jpg
#   inflating: test/6011.jpg
#   inflating: test/6012.jpg
#   inflating: test/6013.jpg
#   inflating: test/6014.jpg
#   inflating: test/6015.jpg
#   inflating: test/6016.jpg
#   inflating: test/6017.jpg
#   inflating: test/6018.jpg
#   inflating: test/6019.jpg
#   inflating: test/602.jpg
#   inflating: test/6020.jpg
#   inflating: test/6021.jpg
#   inflating: test/6022.jpg
#   inflating: test/6023.jpg
#   inflating: test/6024.jpg
#   inflating: test/6025.jpg
#   inflating: test/6026.jpg
#   inflating: test/6027.jpg
#   inflating: test/6028.jpg
#   inflating: test/6029.jpg
#   inflating: test/603.jpg
#   inflating: test/6030.jpg
#   inflating: test/6031.jpg
#   inflating: test/6032.jpg
#   inflating: test/6033.jpg
#   inflating: test/6034.jpg
#   inflating: test/6035.jpg
#   inflating: test/6036.jpg
#   inflating: test/6037.jpg
#   inflating: test/6038.jpg
#   inflating: test/6039.jpg
#   inflating: test/604.jpg
#   inflating: test/6040.jpg
#   inflating: test/6041.jpg
#   inflating: test/6042.jpg
#   inflating: test/6043.jpg
#   inflating: test/6044.jpg
#   inflating: test/6045.jpg
#   inflating: test/6046.jpg
#   inflating: test/6047.jpg
#   inflating: test/6048.jpg
#   inflating: test/6049.jpg
#   inflating: test/605.jpg
#   inflating: test/6050.jpg
#   inflating: test/6051.jpg
#   inflating: test/6052.jpg
#   inflating: test/6053.jpg
#   inflating: test/6054.jpg
#   inflating: test/6055.jpg
#   inflating: test/6056.jpg
#   inflating: test/6057.jpg
#   inflating: test/6058.jpg
#   inflating: test/6059.jpg
#   inflating: test/606.jpg
#   inflating: test/6060.jpg
#   inflating: test/6061.jpg
#   inflating: test/6062.jpg
#   inflating: test/6063.jpg
#   inflating: test/6064.jpg
#   inflating: test/6065.jpg
#   inflating: test/6066.jpg
#   inflating: test/6067.jpg
#   inflating: test/6068.jpg
#   inflating: test/6069.jpg
#   inflating: test/607.jpg
#   inflating: test/6070.jpg
#   inflating: test/6071.jpg
#   inflating: test/6072.jpg
#   inflating: test/6073.jpg
#   inflating: test/6074.jpg
#   inflating: test/6075.jpg
#   inflating: test/6076.jpg
#   inflating: test/6077.jpg
#   inflating: test/6078.jpg
#   inflating: test/6079.jpg
#   inflating: test/608.jpg
#   inflating: test/6080.jpg
#   inflating: test/6081.jpg
#   inflating: test/6082.jpg
#   inflating: test/6083.jpg
#   inflating: test/6084.jpg
#   inflating: test/6085.jpg
#   inflating: test/6086.jpg
#   inflating: test/6087.jpg
#   inflating: test/6088.jpg
#   inflating: test/6089.jpg
#   inflating: test/609.jpg
#   inflating: test/6090.jpg
#   inflating: test/6091.jpg
#   inflating: test/6092.jpg
#   inflating: test/6093.jpg
#   inflating: test/6094.jpg
#   inflating: test/6095.jpg
#   inflating: test/6096.jpg
#   inflating: test/6097.jpg
#   inflating: test/6098.jpg
#   inflating: test/6099.jpg
#   inflating: test/61.jpg
#   inflating: test/610.jpg
#   inflating: test/6100.jpg
#   inflating: test/6101.jpg
#   inflating: test/6102.jpg
#   inflating: test/6103.jpg
#   inflating: test/6104.jpg
#   inflating: test/6105.jpg
#   inflating: test/6106.jpg
#   inflating: test/6107.jpg
#   inflating: test/6108.jpg
#   inflating: test/6109.jpg
#   inflating: test/611.jpg
#   inflating: test/6110.jpg
#   inflating: test/6111.jpg
#   inflating: test/6112.jpg
#   inflating: test/6113.jpg
#   inflating: test/6114.jpg
#   inflating: test/6115.jpg
#   inflating: test/6116.jpg
#   inflating: test/6117.jpg
#   inflating: test/6118.jpg
#   inflating: test/6119.jpg
#   inflating: test/612.jpg
#   inflating: test/6120.jpg
#   inflating: test/6121.jpg
#   inflating: test/6122.jpg
#   inflating: test/6123.jpg
#   inflating: test/6124.jpg
#   inflating: test/6125.jpg
#   inflating: test/6126.jpg
#   inflating: test/6127.jpg
#   inflating: test/6128.jpg
#   inflating: test/6129.jpg
#   inflating: test/613.jpg
#   inflating: test/6130.jpg
#   inflating: test/6131.jpg
#   inflating: test/6132.jpg
#   inflating: test/6133.jpg
#   inflating: test/6134.jpg
#   inflating: test/6135.jpg
#   inflating: test/6136.jpg
#   inflating: test/6137.jpg
#   inflating: test/6138.jpg
#   inflating: test/6139.jpg
#   inflating: test/614.jpg
#   inflating: test/6140.jpg
#   inflating: test/6141.jpg
#   inflating: test/6142.jpg
#   inflating: test/6143.jpg
#   inflating: test/6144.jpg
#   inflating: test/6145.jpg
#   inflating: test/6146.jpg
#   inflating: test/6147.jpg
#   inflating: test/6148.jpg
#   inflating: test/6149.jpg
#   inflating: test/615.jpg
#   inflating: test/6150.jpg
#   inflating: test/6151.jpg
#   inflating: test/6152.jpg
#   inflating: test/6153.jpg
#   inflating: test/6154.jpg
#   inflating: test/6155.jpg
#   inflating: test/6156.jpg
#   inflating: test/6157.jpg
#   inflating: test/6158.jpg
#   inflating: test/6159.jpg
#   inflating: test/616.jpg
#   inflating: test/6160.jpg
#   inflating: test/6161.jpg
#   inflating: test/6162.jpg
#   inflating: test/6163.jpg
#   inflating: test/6164.jpg
#   inflating: test/6165.jpg
#   inflating: test/6166.jpg
#   inflating: test/6167.jpg
#   inflating: test/6168.jpg
#   inflating: test/6169.jpg
#   inflating: test/617.jpg
#   inflating: test/6170.jpg
#   inflating: test/6171.jpg
#   inflating: test/6172.jpg
#   inflating: test/6173.jpg
#   inflating: test/6174.jpg
#   inflating: test/6175.jpg
#   inflating: test/6176.jpg
#   inflating: test/6177.jpg
#   inflating: test/6178.jpg
#   inflating: test/6179.jpg
#   inflating: test/618.jpg
#   inflating: test/6180.jpg
#   inflating: test/6181.jpg
#   inflating: test/6182.jpg
#   inflating: test/6183.jpg
#   inflating: test/6184.jpg
#   inflating: test/6185.jpg
#   inflating: test/6186.jpg
#   inflating: test/6187.jpg
#   inflating: test/6188.jpg
#   inflating: test/6189.jpg
#   inflating: test/619.jpg
#   inflating: test/6190.jpg
#   inflating: test/6191.jpg
#   inflating: test/6192.jpg
#   inflating: test/6193.jpg
#   inflating: test/6194.jpg
#   inflating: test/6195.jpg
#   inflating: test/6196.jpg
#   inflating: test/6197.jpg
#   inflating: test/6198.jpg
#   inflating: test/6199.jpg
#   inflating: test/62.jpg
#   inflating: test/620.jpg
#   inflating: test/6200.jpg
#   inflating: test/6201.jpg
#   inflating: test/6202.jpg
#   inflating: test/6203.jpg
#   inflating: test/6204.jpg
#   inflating: test/6205.jpg
#   inflating: test/6206.jpg
#   inflating: test/6207.jpg
#   inflating: test/6208.jpg
#   inflating: test/6209.jpg
#   inflating: test/621.jpg
#   inflating: test/6210.jpg
#   inflating: test/6211.jpg
#   inflating: test/6212.jpg
#   inflating: test/6213.jpg
#   inflating: test/6214.jpg
#   inflating: test/6215.jpg
#   inflating: test/6216.jpg
#   inflating: test/6217.jpg
#   inflating: test/6218.jpg
#   inflating: test/6219.jpg
#   inflating: test/622.jpg
#   inflating: test/6220.jpg
#   inflating: test/6221.jpg
#   inflating: test/6222.jpg
#   inflating: test/6223.jpg
#   inflating: test/6224.jpg
#   inflating: test/6225.jpg
#   inflating: test/6226.jpg
#   inflating: test/6227.jpg
#   inflating: test/6228.jpg
#   inflating: test/6229.jpg
#   inflating: test/623.jpg
#   inflating: test/6230.jpg
#   inflating: test/6231.jpg
#   inflating: test/6232.jpg
#   inflating: test/6233.jpg
#   inflating: test/6234.jpg
#   inflating: test/6235.jpg
#   inflating: test/6236.jpg
#   inflating: test/6237.jpg
#   inflating: test/6238.jpg
#   inflating: test/6239.jpg
#   inflating: test/624.jpg
#   inflating: test/6240.jpg
#   inflating: test/6241.jpg
#   inflating: test/6242.jpg
#   inflating: test/6243.jpg
#   inflating: test/6244.jpg
#   inflating: test/6245.jpg
#   inflating: test/6246.jpg
#   inflating: test/6247.jpg
#   inflating: test/6248.jpg
#   inflating: test/6249.jpg
#   inflating: test/625.jpg
#   inflating: test/6250.jpg
#   inflating: test/6251.jpg
#   inflating: test/6252.jpg
#   inflating: test/6253.jpg
#   inflating: test/6254.jpg
#   inflating: test/6255.jpg
#   inflating: test/6256.jpg
#   inflating: test/6257.jpg
#   inflating: test/6258.jpg
#   inflating: test/6259.jpg
#   inflating: test/626.jpg
#   inflating: test/6260.jpg
#   inflating: test/6261.jpg
#   inflating: test/6262.jpg
#   inflating: test/6263.jpg
#   inflating: test/6264.jpg
#   inflating: test/6265.jpg
#   inflating: test/6266.jpg
#   inflating: test/6267.jpg
#   inflating: test/6268.jpg
#   inflating: test/6269.jpg
#   inflating: test/627.jpg
#   inflating: test/6270.jpg
#   inflating: test/6271.jpg
#   inflating: test/6272.jpg
#   inflating: test/6273.jpg
#   inflating: test/6274.jpg
#   inflating: test/6275.jpg
#   inflating: test/6276.jpg
#   inflating: test/6277.jpg
#   inflating: test/6278.jpg
#   inflating: test/6279.jpg
#   inflating: test/628.jpg
#   inflating: test/6280.jpg
#   inflating: test/6281.jpg
#   inflating: test/6282.jpg
#   inflating: test/6283.jpg
#   inflating: test/6284.jpg
#   inflating: test/6285.jpg
#   inflating: test/6286.jpg
#   inflating: test/6287.jpg
#   inflating: test/6288.jpg
#   inflating: test/6289.jpg
#   inflating: test/629.jpg
#   inflating: test/6290.jpg
#   inflating: test/6291.jpg
#   inflating: test/6292.jpg
#   inflating: test/6293.jpg
#   inflating: test/6294.jpg
#   inflating: test/6295.jpg
#   inflating: test/6296.jpg
#   inflating: test/6297.jpg
#   inflating: test/6298.jpg
#   inflating: test/6299.jpg
#   inflating: test/63.jpg
#   inflating: test/630.jpg
#   inflating: test/6300.jpg
#   inflating: test/6301.jpg
#   inflating: test/6302.jpg
#   inflating: test/6303.jpg
#   inflating: test/6304.jpg
#   inflating: test/6305.jpg
#   inflating: test/6306.jpg
#   inflating: test/6307.jpg
#   inflating: test/6308.jpg
#   inflating: test/6309.jpg
#   inflating: test/631.jpg
#   inflating: test/6310.jpg
#   inflating: test/6311.jpg
#   inflating: test/6312.jpg
#   inflating: test/6313.jpg
#   inflating: test/6314.jpg
#   inflating: test/6315.jpg
#   inflating: test/6316.jpg
#   inflating: test/6317.jpg
#   inflating: test/6318.jpg
#   inflating: test/6319.jpg
#   inflating: test/632.jpg
#   inflating: test/6320.jpg
#   inflating: test/6321.jpg
#   inflating: test/6322.jpg
#   inflating: test/6323.jpg
#   inflating: test/6324.jpg
#   inflating: test/6325.jpg
#   inflating: test/6326.jpg
#   inflating: test/6327.jpg
#   inflating: test/6328.jpg
#   inflating: test/6329.jpg
#   inflating: test/633.jpg
#   inflating: test/6330.jpg
#   inflating: test/6331.jpg
#   inflating: test/6332.jpg
#   inflating: test/6333.jpg
#   inflating: test/6334.jpg
#   inflating: test/6335.jpg
#   inflating: test/6336.jpg
#   inflating: test/6337.jpg
#   inflating: test/6338.jpg
#   inflating: test/6339.jpg
#   inflating: test/634.jpg
#   inflating: test/6340.jpg
#   inflating: test/6341.jpg
#   inflating: test/6342.jpg
#   inflating: test/6343.jpg
#   inflating: test/6344.jpg
#   inflating: test/6345.jpg
#   inflating: test/6346.jpg
#   inflating: test/6347.jpg
#   inflating: test/6348.jpg
#   inflating: test/6349.jpg
#   inflating: test/635.jpg
#   inflating: test/6350.jpg
#   inflating: test/6351.jpg
#   inflating: test/6352.jpg
#   inflating: test/6353.jpg
#   inflating: test/6354.jpg
#   inflating: test/6355.jpg
#   inflating: test/6356.jpg
#   inflating: test/6357.jpg
#   inflating: test/6358.jpg
#   inflating: test/6359.jpg
#   inflating: test/636.jpg
#   inflating: test/6360.jpg
#   inflating: test/6361.jpg
#   inflating: test/6362.jpg
#   inflating: test/6363.jpg
#   inflating: test/6364.jpg
#   inflating: test/6365.jpg
#   inflating: test/6366.jpg
#   inflating: test/6367.jpg
#   inflating: test/6368.jpg
#   inflating: test/6369.jpg
#   inflating: test/637.jpg
#   inflating: test/6370.jpg
#   inflating: test/6371.jpg
#   inflating: test/6372.jpg
#   inflating: test/6373.jpg
#   inflating: test/6374.jpg
#   inflating: test/6375.jpg
#   inflating: test/6376.jpg
#   inflating: test/6377.jpg
#   inflating: test/6378.jpg
#   inflating: test/6379.jpg
#   inflating: test/638.jpg
#   inflating: test/6380.jpg
#   inflating: test/6381.jpg
#   inflating: test/6382.jpg
#   inflating: test/6383.jpg
#   inflating: test/6384.jpg
#   inflating: test/6385.jpg
#   inflating: test/6386.jpg
#   inflating: test/6387.jpg
#   inflating: test/6388.jpg
#   inflating: test/6389.jpg
#   inflating: test/639.jpg
#   inflating: test/6390.jpg
#   inflating: test/6391.jpg
#   inflating: test/6392.jpg
#   inflating: test/6393.jpg
#   inflating: test/6394.jpg
#   inflating: test/6395.jpg
#   inflating: test/6396.jpg
#   inflating: test/6397.jpg
#   inflating: test/6398.jpg
#   inflating: test/6399.jpg
#   inflating: test/64.jpg
#   inflating: test/640.jpg
#   inflating: test/6400.jpg
#   inflating: test/6401.jpg
#   inflating: test/6402.jpg
#   inflating: test/6403.jpg
#   inflating: test/6404.jpg
#   inflating: test/6405.jpg
#   inflating: test/6406.jpg
#   inflating: test/6407.jpg
#   inflating: test/6408.jpg
#   inflating: test/6409.jpg
#   inflating: test/641.jpg
#   inflating: test/6410.jpg
#   inflating: test/6411.jpg
#   inflating: test/6412.jpg
#   inflating: test/6413.jpg
#   inflating: test/6414.jpg
#   inflating: test/6415.jpg
#   inflating: test/6416.jpg
#   inflating: test/6417.jpg
#   inflating: test/6418.jpg
#   inflating: test/6419.jpg
#   inflating: test/642.jpg
#   inflating: test/6420.jpg
#   inflating: test/6421.jpg
#   inflating: test/6422.jpg
#   inflating: test/6423.jpg
#   inflating: test/6424.jpg
#   inflating: test/6425.jpg
#   inflating: test/6426.jpg
#   inflating: test/6427.jpg
#   inflating: test/6428.jpg
#   inflating: test/6429.jpg
#   inflating: test/643.jpg
#   inflating: test/6430.jpg
#   inflating: test/6431.jpg
#   inflating: test/6432.jpg
#   inflating: test/6433.jpg
#   inflating: test/6434.jpg
#   inflating: test/6435.jpg
#   inflating: test/6436.jpg
#   inflating: test/6437.jpg
#   inflating: test/6438.jpg
#   inflating: test/6439.jpg
#   inflating: test/644.jpg
#   inflating: test/6440.jpg
#   inflating: test/6441.jpg
#   inflating: test/6442.jpg
#   inflating: test/6443.jpg
#   inflating: test/6444.jpg
#   inflating: test/6445.jpg
#   inflating: test/6446.jpg
#   inflating: test/6447.jpg
#   inflating: test/6448.jpg
#   inflating: test/6449.jpg
#   inflating: test/645.jpg
#   inflating: test/6450.jpg
#   inflating: test/6451.jpg
#   inflating: test/6452.jpg
#   inflating: test/6453.jpg
#   inflating: test/6454.jpg
#   inflating: test/6455.jpg
#   inflating: test/6456.jpg
#   inflating: test/6457.jpg
#   inflating: test/6458.jpg
#   inflating: test/6459.jpg
#   inflating: test/646.jpg
#   inflating: test/6460.jpg
#   inflating: test/6461.jpg
#   inflating: test/6462.jpg
#   inflating: test/6463.jpg
#   inflating: test/6464.jpg
#   inflating: test/6465.jpg
#   inflating: test/6466.jpg
#   inflating: test/6467.jpg
#   inflating: test/6468.jpg
#   inflating: test/6469.jpg
#   inflating: test/647.jpg
#   inflating: test/6470.jpg
#   inflating: test/6471.jpg
#   inflating: test/6472.jpg
#   inflating: test/6473.jpg
#   inflating: test/6474.jpg
#   inflating: test/6475.jpg
#   inflating: test/6476.jpg
#   inflating: test/6477.jpg
#   inflating: test/6478.jpg
#   inflating: test/6479.jpg
#   inflating: test/648.jpg
#   inflating: test/6480.jpg
#   inflating: test/6481.jpg
#   inflating: test/6482.jpg
#   inflating: test/6483.jpg
#   inflating: test/6484.jpg
#   inflating: test/6485.jpg
#   inflating: test/6486.jpg
#   inflating: test/6487.jpg
#   inflating: test/6488.jpg
#   inflating: test/6489.jpg
#   inflating: test/649.jpg
#   inflating: test/6490.jpg
#   inflating: test/6491.jpg
#   inflating: test/6492.jpg
#   inflating: test/6493.jpg
#   inflating: test/6494.jpg
#   inflating: test/6495.jpg
#   inflating: test/6496.jpg
#   inflating: test/6497.jpg
#   inflating: test/6498.jpg
#   inflating: test/6499.jpg
#   inflating: test/65.jpg
#   inflating: test/650.jpg
#   inflating: test/6500.jpg
#   inflating: test/6501.jpg
#   inflating: test/6502.jpg
#   inflating: test/6503.jpg
#   inflating: test/6504.jpg
#   inflating: test/6505.jpg
#   inflating: test/6506.jpg
#   inflating: test/6507.jpg
#   inflating: test/6508.jpg
#   inflating: test/6509.jpg
#   inflating: test/651.jpg
#   inflating: test/6510.jpg
#   inflating: test/6511.jpg
#   inflating: test/6512.jpg
#   inflating: test/6513.jpg
#   inflating: test/6514.jpg
#   inflating: test/6515.jpg
#   inflating: test/6516.jpg
#   inflating: test/6517.jpg
#   inflating: test/6518.jpg
#   inflating: test/6519.jpg
#   inflating: test/652.jpg
#   inflating: test/6520.jpg
#   inflating: test/6521.jpg
#   inflating: test/6522.jpg
#   inflating: test/6523.jpg
#   inflating: test/6524.jpg
#   inflating: test/6525.jpg
#   inflating: test/6526.jpg
#   inflating: test/6527.jpg
#   inflating: test/6528.jpg
#   inflating: test/6529.jpg
#   inflating: test/653.jpg
#   inflating: test/6530.jpg
#   inflating: test/6531.jpg
#   inflating: test/6532.jpg
#   inflating: test/6533.jpg
#   inflating: test/6534.jpg
#   inflating: test/6535.jpg
#   inflating: test/6536.jpg
#   inflating: test/6537.jpg
#   inflating: test/6538.jpg
#   inflating: test/6539.jpg
#   inflating: test/654.jpg
#   inflating: test/6540.jpg
#   inflating: test/6541.jpg
#   inflating: test/6542.jpg
#   inflating: test/6543.jpg
#   inflating: test/6544.jpg
#   inflating: test/6545.jpg
#   inflating: test/6546.jpg
#   inflating: test/6547.jpg
#   inflating: test/6548.jpg
#   inflating: test/6549.jpg
#   inflating: test/655.jpg
#   inflating: test/6550.jpg
#   inflating: test/6551.jpg
#   inflating: test/6552.jpg
#   inflating: test/6553.jpg
#   inflating: test/6554.jpg
#   inflating: test/6555.jpg
#   inflating: test/6556.jpg
#   inflating: test/6557.jpg
#   inflating: test/6558.jpg
#   inflating: test/6559.jpg
#   inflating: test/656.jpg
#   inflating: test/6560.jpg
#   inflating: test/6561.jpg
#   inflating: test/6562.jpg
#   inflating: test/6563.jpg
#   inflating: test/6564.jpg
#   inflating: test/6565.jpg
#   inflating: test/6566.jpg
#   inflating: test/6567.jpg
#   inflating: test/6568.jpg
#   inflating: test/6569.jpg
#   inflating: test/657.jpg
#   inflating: test/6570.jpg
#   inflating: test/6571.jpg
#   inflating: test/6572.jpg
#   inflating: test/6573.jpg
#   inflating: test/6574.jpg
#   inflating: test/6575.jpg
#   inflating: test/6576.jpg
#   inflating: test/6577.jpg
#   inflating: test/6578.jpg
#   inflating: test/6579.jpg
#   inflating: test/658.jpg
#   inflating: test/6580.jpg
#   inflating: test/6581.jpg
#   inflating: test/6582.jpg
#   inflating: test/6583.jpg
#   inflating: test/6584.jpg
#   inflating: test/6585.jpg
#   inflating: test/6586.jpg
#   inflating: test/6587.jpg
#   inflating: test/6588.jpg
#   inflating: test/6589.jpg
#   inflating: test/659.jpg
#   inflating: test/6590.jpg
#   inflating: test/6591.jpg
#   inflating: test/6592.jpg
#   inflating: test/6593.jpg
#   inflating: test/6594.jpg
#   inflating: test/6595.jpg
#   inflating: test/6596.jpg
#   inflating: test/6597.jpg
#   inflating: test/6598.jpg
#   inflating: test/6599.jpg
#   inflating: test/66.jpg
#   inflating: test/660.jpg
#   inflating: test/6600.jpg
#   inflating: test/6601.jpg
#   inflating: test/6602.jpg
#   inflating: test/6603.jpg
#   inflating: test/6604.jpg
#   inflating: test/6605.jpg
#   inflating: test/6606.jpg
#   inflating: test/6607.jpg
#   inflating: test/6608.jpg
#   inflating: test/6609.jpg
#   inflating: test/661.jpg
#   inflating: test/6610.jpg
#   inflating: test/6611.jpg
#   inflating: test/6612.jpg
#   inflating: test/6613.jpg
#   inflating: test/6614.jpg
#   inflating: test/6615.jpg
#   inflating: test/6616.jpg
#   inflating: test/6617.jpg
#   inflating: test/6618.jpg
#   inflating: test/6619.jpg
#   inflating: test/662.jpg
#   inflating: test/6620.jpg
#   inflating: test/6621.jpg
#   inflating: test/6622.jpg
#   inflating: test/6623.jpg
#   inflating: test/6624.jpg
#   inflating: test/6625.jpg
#   inflating: test/6626.jpg
#   inflating: test/6627.jpg
#   inflating: test/6628.jpg
#   inflating: test/6629.jpg
#   inflating: test/663.jpg
#   inflating: test/6630.jpg
#   inflating: test/6631.jpg
#   inflating: test/6632.jpg
# ...
#   inflating: test/962.jpg
#   inflating: test/9620.jpg
#   inflating: test/9621.jpg
#   inflating: test/9622.jpg
#   inflating: test/9623.jpg
#   inflating: test/9624.jpg
#   inflating: test/9625.jpg
#   inflating: test/9626.jpg
#   inflating: test/9627.jpg
#   inflating: test/9628.jpg
#   inflating: test/9629.jpg
#   inflating: test/963.jpg
#   inflating: test/9630.jpg
#   inflating: test/9631.jpg
#   inflating: test/9632.jpg
#   inflating: test/9633.jpg
#   inflating: test/9634.jpg
#   inflating: test/9635.jpg
#   inflating: test/9636.jpg
#   inflating: test/9637.jpg
#   inflating: test/9638.jpg
#   inflating: test/9639.jpg
#   inflating: test/964.jpg
#   inflating: test/9640.jpg
#   inflating: test/9641.jpg
#   inflating: test/9642.jpg
#   inflating: test/9643.jpg
#   inflating: test/9644.jpg
#   inflating: test/9645.jpg
#   inflating: test/9646.jpg
#   inflating: test/9647.jpg
#   inflating: test/9648.jpg
#   inflating: test/9649.jpg
#   inflating: test/965.jpg
#   inflating: test/9650.jpg
#   inflating: test/9651.jpg
#   inflating: test/9652.jpg
#   inflating: test/9653.jpg
#   inflating: test/9654.jpg
#   inflating: test/9655.jpg
#   inflating: test/9656.jpg
#   inflating: test/9657.jpg
#   inflating: test/9658.jpg
#   inflating: test/9659.jpg
#   inflating: test/966.jpg
#   inflating: test/9660.jpg
#   inflating: test/9661.jpg
#   inflating: test/9662.jpg
#   inflating: test/9663.jpg
#   inflating: test/9664.jpg
#   inflating: test/9665.jpg
#   inflating: test/9666.jpg
#   inflating: test/9667.jpg
#   inflating: test/9668.jpg
#   inflating: test/9669.jpg
#   inflating: test/967.jpg
#   inflating: test/9670.jpg
#   inflating: test/9671.jpg
#   inflating: test/9672.jpg
#   inflating: test/9673.jpg
#   inflating: test/9674.jpg
#   inflating: test/9675.jpg
#   inflating: test/9676.jpg
#   inflating: test/9677.jpg
#   inflating: test/9678.jpg
#   inflating: test/9679.jpg
#   inflating: test/968.jpg
#   inflating: test/9680.jpg
#   inflating: test/9681.jpg
#   inflating: test/9682.jpg
#   inflating: test/9683.jpg
#   inflating: test/9684.jpg
#   inflating: test/9685.jpg
#   inflating: test/9686.jpg
#   inflating: test/9687.jpg
#   inflating: test/9688.jpg
#   inflating: test/9689.jpg
#   inflating: test/969.jpg
#   inflating: test/9690.jpg
#   inflating: test/9691.jpg
#   inflating: test/9692.jpg
#   inflating: test/9693.jpg
#   inflating: test/9694.jpg
#   inflating: test/9695.jpg
#   inflating: test/9696.jpg
#   inflating: test/9697.jpg
#   inflating: test/9698.jpg
#   inflating: test/9699.jpg
#   inflating: test/97.jpg
#   inflating: test/970.jpg
#   inflating: test/9700.jpg
#   inflating: test/9701.jpg
#   inflating: test/9702.jpg
#   inflating: test/9703.jpg
#   inflating: test/9704.jpg
#   inflating: test/9705.jpg
#   inflating: test/9706.jpg
#   inflating: test/9707.jpg
#   inflating: test/9708.jpg
#   inflating: test/9709.jpg
#   inflating: test/971.jpg
#   inflating: test/9710.jpg
#   inflating: test/9711.jpg
#   inflating: test/9712.jpg
#   inflating: test/9713.jpg
#   inflating: test/9714.jpg
#   inflating: test/9715.jpg
#   inflating: test/9716.jpg
#   inflating: test/9717.jpg
#   inflating: test/9718.jpg
#   inflating: test/9719.jpg
#   inflating: test/972.jpg
#   inflating: test/9720.jpg
#   inflating: test/9721.jpg
#   inflating: test/9722.jpg
#   inflating: test/9723.jpg
#   inflating: test/9724.jpg
#   inflating: test/9725.jpg
#   inflating: test/9726.jpg
#   inflating: test/9727.jpg
#   inflating: test/9728.jpg
#   inflating: test/9729.jpg
#   inflating: test/973.jpg
#   inflating: test/9730.jpg
#   inflating: test/9731.jpg
#   inflating: test/9732.jpg
#   inflating: test/9733.jpg
#   inflating: test/9734.jpg
#   inflating: test/9735.jpg
#   inflating: test/9736.jpg
#   inflating: test/9737.jpg
#   inflating: test/9738.jpg
#   inflating: test/9739.jpg
#   inflating: test/974.jpg
#   inflating: test/9740.jpg
#   inflating: test/9741.jpg
#   inflating: test/9742.jpg
#   inflating: test/9743.jpg
#   inflating: test/9744.jpg
#   inflating: test/9745.jpg
#   inflating: test/9746.jpg
#   inflating: test/9747.jpg
#   inflating: test/9748.jpg
#   inflating: test/9749.jpg
#   inflating: test/975.jpg
#   inflating: test/9750.jpg
#   inflating: test/9751.jpg
#   inflating: test/9752.jpg
#   inflating: test/9753.jpg
#   inflating: test/9754.jpg
#   inflating: test/9755.jpg
#   inflating: test/9756.jpg
#   inflating: test/9757.jpg
#   inflating: test/9758.jpg
#   inflating: test/9759.jpg
#   inflating: test/976.jpg
#   inflating: test/9760.jpg
#   inflating: test/9761.jpg
#   inflating: test/9762.jpg
#   inflating: test/9763.jpg
#   inflating: test/9764.jpg
#   inflating: test/9765.jpg
#   inflating: test/9766.jpg
#   inflating: test/9767.jpg
#   inflating: test/9768.jpg
#   inflating: test/9769.jpg
#   inflating: test/977.jpg
#   inflating: test/9770.jpg
#   inflating: test/9771.jpg
#   inflating: test/9772.jpg
#   inflating: test/9773.jpg
#   inflating: test/9774.jpg
#   inflating: test/9775.jpg
#   inflating: test/9776.jpg
#   inflating: test/9777.jpg
#   inflating: test/9778.jpg
#   inflating: test/9779.jpg
#   inflating: test/978.jpg
#   inflating: test/9780.jpg
#   inflating: test/9781.jpg
#   inflating: test/9782.jpg
#   inflating: test/9783.jpg
#   inflating: test/9784.jpg
#   inflating: test/9785.jpg
#   inflating: test/9786.jpg
#   inflating: test/9787.jpg
#   inflating: test/9788.jpg
#   inflating: test/9789.jpg
#   inflating: test/979.jpg
#   inflating: test/9790.jpg
#   inflating: test/9791.jpg
#   inflating: test/9792.jpg
#   inflating: test/9793.jpg
#   inflating: test/9794.jpg
#   inflating: test/9795.jpg
#   inflating: test/9796.jpg
#   inflating: test/9797.jpg
#   inflating: test/9798.jpg
#   inflating: test/9799.jpg
#   inflating: test/98.jpg
#   inflating: test/980.jpg
#   inflating: test/9800.jpg
#   inflating: test/9801.jpg
#   inflating: test/9802.jpg
#   inflating: test/9803.jpg
#   inflating: test/9804.jpg
#   inflating: test/9805.jpg
#   inflating: test/9806.jpg
#   inflating: test/9807.jpg
#   inflating: test/9808.jpg
#   inflating: test/9809.jpg
#   inflating: test/981.jpg
#   inflating: test/9810.jpg
#   inflating: test/9811.jpg
#   inflating: test/9812.jpg
#   inflating: test/9813.jpg
#   inflating: test/9814.jpg
#   inflating: test/9815.jpg
#   inflating: test/9816.jpg
#   inflating: test/9817.jpg
#   inflating: test/9818.jpg
#   inflating: test/9819.jpg
#   inflating: test/982.jpg
#   inflating: test/9820.jpg
#   inflating: test/9821.jpg
#   inflating: test/9822.jpg
#   inflating: test/9823.jpg
#   inflating: test/9824.jpg
#   inflating: test/9825.jpg
#   inflating: test/9826.jpg
#   inflating: test/9827.jpg
#   inflating: test/9828.jpg
#   inflating: test/9829.jpg
#   inflating: test/983.jpg
#   inflating: test/9830.jpg
#   inflating: test/9831.jpg
#   inflating: test/9832.jpg
#   inflating: test/9833.jpg
#   inflating: test/9834.jpg
#   inflating: test/9835.jpg
#   inflating: test/9836.jpg
#   inflating: test/9837.jpg
#   inflating: test/9838.jpg
#   inflating: test/9839.jpg
#   inflating: test/984.jpg
#   inflating: test/9840.jpg
#   inflating: test/9841.jpg
#   inflating: test/9842.jpg
#   inflating: test/9843.jpg
#   inflating: test/9844.jpg
#   inflating: test/9845.jpg
#   inflating: test/9846.jpg
#   inflating: test/9847.jpg
#   inflating: test/9848.jpg
#   inflating: test/9849.jpg
#   inflating: test/985.jpg
#   inflating: test/9850.jpg
#   inflating: test/9851.jpg
#   inflating: test/9852.jpg
#   inflating: test/9853.jpg
#   inflating: test/9854.jpg
#   inflating: test/9855.jpg
#   inflating: test/9856.jpg
#   inflating: test/9857.jpg
#   inflating: test/9858.jpg
#   inflating: test/9859.jpg
#   inflating: test/986.jpg
#   inflating: test/9860.jpg
#   inflating: test/9861.jpg
#   inflating: test/9862.jpg
#   inflating: test/9863.jpg
#   inflating: test/9864.jpg
#   inflating: test/9865.jpg
#   inflating: test/9866.jpg
#   inflating: test/9867.jpg
#   inflating: test/9868.jpg
#   inflating: test/9869.jpg
#   inflating: test/987.jpg
#   inflating: test/9870.jpg
#   inflating: test/9871.jpg
#   inflating: test/9872.jpg
#   inflating: test/9873.jpg
#   inflating: test/9874.jpg
#   inflating: test/9875.jpg
#   inflating: test/9876.jpg
#   inflating: test/9877.jpg
#   inflating: test/9878.jpg
#   inflating: test/9879.jpg
#   inflating: test/988.jpg
#   inflating: test/9880.jpg
#   inflating: test/9881.jpg
#   inflating: test/9882.jpg
#   inflating: test/9883.jpg
#   inflating: test/9884.jpg
#   inflating: test/9885.jpg
#   inflating: test/9886.jpg
#   inflating: test/9887.jpg
#   inflating: test/9888.jpg
#   inflating: test/9889.jpg
#   inflating: test/989.jpg
#   inflating: test/9890.jpg
#   inflating: test/9891.jpg
#   inflating: test/9892.jpg
#   inflating: test/9893.jpg
#   inflating: test/9894.jpg
#   inflating: test/9895.jpg
#   inflating: test/9896.jpg
#   inflating: test/9897.jpg
#   inflating: test/9898.jpg
#   inflating: test/9899.jpg
#   inflating: test/99.jpg
#   inflating: test/990.jpg
#   inflating: test/9900.jpg
#   inflating: test/9901.jpg
#   inflating: test/9902.jpg
#   inflating: test/9903.jpg
#   inflating: test/9904.jpg
#   inflating: test/9905.jpg
#   inflating: test/9906.jpg
#   inflating: test/9907.jpg
#   inflating: test/9908.jpg
#   inflating: test/9909.jpg
#   inflating: test/991.jpg
#   inflating: test/9910.jpg
#   inflating: test/9911.jpg
#   inflating: test/9912.jpg
#   inflating: test/9913.jpg
#   inflating: test/9914.jpg
#   inflating: test/9915.jpg
#   inflating: test/9916.jpg
#   inflating: test/9917.jpg
#   inflating: test/9918.jpg
#   inflating: test/9919.jpg
#   inflating: test/992.jpg
#   inflating: test/9920.jpg
#   inflating: test/9921.jpg
#   inflating: test/9922.jpg
#   inflating: test/9923.jpg
#   inflating: test/9924.jpg
#   inflating: test/9925.jpg
#   inflating: test/9926.jpg
#   inflating: test/9927.jpg
#   inflating: test/9928.jpg
#   inflating: test/9929.jpg
#   inflating: test/993.jpg
#   inflating: test/9930.jpg
#   inflating: test/9931.jpg
#   inflating: test/9932.jpg
#   inflating: test/9933.jpg
#   inflating: test/9934.jpg
#   inflating: test/9935.jpg
#   inflating: test/9936.jpg
#   inflating: test/9937.jpg
#   inflating: test/9938.jpg
#   inflating: test/9939.jpg
#   inflating: test/994.jpg
#   inflating: test/9940.jpg
#   inflating: test/9941.jpg
#   inflating: test/9942.jpg
#   inflating: test/9943.jpg
#   inflating: test/9944.jpg
#   inflating: test/9945.jpg
#   inflating: test/9946.jpg
#   inflating: test/9947.jpg
#   inflating: test/9948.jpg
#   inflating: test/9949.jpg
#   inflating: test/995.jpg
#   inflating: test/9950.jpg
#   inflating: test/9951.jpg
#   inflating: test/9952.jpg
#   inflating: test/9953.jpg
#   inflating: test/9954.jpg
#   inflating: test/9955.jpg
#   inflating: test/9956.jpg
#   inflating: test/9957.jpg
#   inflating: test/9958.jpg
#   inflating: test/9959.jpg
#   inflating: test/996.jpg
#   inflating: test/9960.jpg
#   inflating: test/9961.jpg
#   inflating: test/9962.jpg
#   inflating: test/9963.jpg
#   inflating: test/9964.jpg
#   inflating: test/9965.jpg
#   inflating: test/9966.jpg
#   inflating: test/9967.jpg
#   inflating: test/9968.jpg
#   inflating: test/9969.jpg
#   inflating: test/997.jpg
#   inflating: test/9970.jpg
#   inflating: test/9971.jpg
#   inflating: test/9972.jpg
#   inflating: test/9973.jpg
#   inflating: test/9974.jpg
#   inflating: test/9975.jpg
#   inflating: test/9976.jpg
#   inflating: test/9977.jpg
#   inflating: test/9978.jpg
#   inflating: test/9979.jpg
#   inflating: test/998.jpg
#   inflating: test/9980.jpg
#   inflating: test/9981.jpg
#   inflating: test/9982.jpg
#   inflating: test/9983.jpg
#   inflating: test/9984.jpg
#   inflating: test/9985.jpg
#   inflating: test/9986.jpg
#   inflating: test/9987.jpg
#   inflating: test/9988.jpg
#   inflating: test/9989.jpg
#   inflating: test/999.jpg
#   inflating: test/9990.jpg
#   inflating: test/9991.jpg
#   inflating: test/9992.jpg
#   inflating: test/9993.jpg
#   inflating: test/9994.jpg
#   inflating: test/9995.jpg
#   inflating: test/9996.jpg
#   inflating: test/9997.jpg
#   inflating: test/9998.jpg
#   inflating: test/9999.jpg

# %% [markdown]
# ### Writing Training Data into DF

# %%
filenames = os.listdir('./train')
categories = []
for filename in filenames:
    category = filename.split('.')[0]
    if category == 'dog':
        categories.append(1)
    else:
        categories.append(0)

df = pd.DataFrame({
    'filename': filenames,
    'category': categories
})

# %%
df
# Out:
#             filename  category
# 0       dog.4388.jpg         1
# 1       dog.6069.jpg         1
# 2      cat.11136.jpg         0
# 3       dog.2509.jpg         1
# 4       cat.4006.jpg         0
# ...              ...       ...
# 24995   dog.8066.jpg         1
# 24996  cat.10191.jpg         0
# 24997  cat.11318.jpg         0
# 24998   dog.6821.jpg         1
# 24999   cat.6520.jpg         0
#
# [25000 rows x 2 columns]

# %% [markdown]
# # EDA

# %%
df['category'] = df['category'].astype(str)
target_counts=df['category'].value_counts()
print("Number of dogs in the dataset:{}".format(target_counts['1']))
print("Number of cats in the dataset:{}".format(target_counts['0']))
# Out:
# Number of dogs in the dataset:12500
# Number of cats in the dataset:12500

# %%
df['category'].value_counts().plot.bar()

# %%
# see sample image
sample = random.choice(filenames)
image = load_img("./train/"+sample)
plt.imshow(image)

# %%
# import required module
from PIL import Image

img = image

# get width and height
width = img.width
height = img.height

# display width and height
print("The height of the image is: ", height)
print("The width of the image is: ", width)
# Out:
# The height of the image is:  500
# The width of the image is:  365

# %% [markdown]
# # Prepare Data

# %%
df.head()
# Out:
#         filename category
# 0   dog.4388.jpg        1
# 1   dog.6069.jpg        1
# 2  cat.11136.jpg        0
# 3   dog.2509.jpg        1
# 4   cat.4006.jpg        0

# %%
df['category'] = df['category'].astype(int)
df['category'] = df['category'].replace({0: 'cat', 1: 'dog'})
df.head()
# Out:
#         filename category
# 0   dog.4388.jpg      dog
# 1   dog.6069.jpg      dog
# 2  cat.11136.jpg      cat
# 3   dog.2509.jpg      dog
# 4   cat.4006.jpg      cat

# %%
df_sorted = df.sort_values(by=['category'])

# %%
df_sorted
# Out:
#            filename category
# 24999  cat.6520.jpg      cat
# 10331  cat.1438.jpg      cat
# 10333  cat.6862.jpg      cat
# 10334  cat.9003.jpg      cat
# 19755  cat.2312.jpg      cat
# ...             ...      ...
# 11020   dog.437.jpg      dog
# 11024  dog.9324.jpg      dog
# 11025  dog.3919.jpg      dog
# 11030  dog.9504.jpg      dog
# 12499  dog.4497.jpg      dog
#
# [25000 rows x 2 columns]

# %% [markdown]
# ## Create a subset

# %%
df_cat = df_sorted.iloc[0:1300]
df_dog = df_sorted.iloc[12500:13800]

# %%
frames = [df_cat, df_dog]

df_subset = pd.concat(frames)

df_subset
# Out:
#             filename category
# 24999   cat.6520.jpg      cat
# 10331   cat.1438.jpg      cat
# 10333   cat.6862.jpg      cat
# 10334   cat.9003.jpg      cat
# 19755   cat.2312.jpg      cat
# ...              ...      ...
# 20881  dog.10042.jpg      dog
# 20882   dog.1725.jpg      dog
# 24333   dog.4327.jpg      dog
# 24807   dog.5097.jpg      dog
# 16876  dog.12219.jpg      dog
#
# [2600 rows x 2 columns]

# %% [markdown]
# #Train-Test Splits

# %% [markdown]
# ## Full Set

# %%
X_full = df_sorted['filename']
Y_full = df_sorted['category']

# %%
X_train_full, X_test_full, y_train_full, y_test_full = train_test_split(X_full, Y_full, test_size=0.20, random_state=42)

train_data = {'filename': X_train_full,
             'category': y_train_full}
train_full_df = pd.concat(train_data, axis=1)
train_full_df = train_full_df.reset_index(drop=True)

validate_full_data = {'filename': X_test_full,
             'category': y_test_full}
validate_full_df = pd.concat(validate_full_data, axis=1)
validate_full_df = validate_full_df.reset_index(drop=True)

# %% [markdown]
# ## Subset

# %%
X = df_subset['filename']
Y = df_subset['category']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.20, random_state=42)

train_data = {'filename': X_train,
             'category': y_train}
train_df = pd.concat(train_data, axis=1)
train_df = train_df.reset_index(drop=True)

validate_data = {'filename': X_test,
             'category': y_test}
validate_df = pd.concat(validate_data, axis=1)
validate_df = validate_df.reset_index(drop=True)

# %%
train_df
# Out:
#            filename category
# 0      cat.3211.jpg      cat
# 1      cat.9948.jpg      cat
# 2      dog.6744.jpg      dog
# 3      cat.5102.jpg      cat
# 4      dog.3174.jpg      dog
# ...             ...      ...
# 2075   dog.4522.jpg      dog
# 2076   cat.7691.jpg      cat
# 2077  cat.10297.jpg      cat
# 2078   cat.8030.jpg      cat
# 2079   cat.7011.jpg      cat
#
# [2080 rows x 2 columns]

# %%
validate_df
# Out:
#           filename category
# 0     dog.9433.jpg      dog
# 1     cat.9630.jpg      cat
# 2      cat.848.jpg      cat
# 3    dog.10043.jpg      dog
# 4     dog.7545.jpg      dog
# ..             ...      ...
# 515   dog.5407.jpg      dog
# 516   cat.9192.jpg      cat
# 517   cat.1030.jpg      cat
# 518   cat.4024.jpg      cat
# 519   dog.5579.jpg      dog
#
# [520 rows x 2 columns]

# %%
train_df['category'].value_counts().plot.bar()

# %%
validate_df['category'].value_counts().plot.bar()

# %% [markdown]
# # Prep Data for Models

# %% [markdown]
# ## Define Constants

# %%
total_train = train_df.shape[0]
total_validate = validate_df.shape[0]
batch_size=15

IMAGE_WIDTH=128
IMAGE_HEIGHT=128
IMAGE_SIZE=(IMAGE_WIDTH, IMAGE_HEIGHT)
IMAGE_CHANNELS=3

# %% [markdown]
# ## Training Generator

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
)

train_generator = train_datagen.flow_from_dataframe(
    train_df,
    "./train/",
    x_col='filename',
    y_col='category',
    target_size=IMAGE_SIZE,
    class_mode='categorical',
    batch_size=batch_size
)
# Out:
# Found 2080 validated image filenames belonging to 2 classes.

# %% [markdown]
# ## Validation Generator

# %%
validation_datagen = ImageDataGenerator(rescale=1./255)
validation_generator = validation_datagen.flow_from_dataframe(
    validate_df,
    "./train/",
    x_col='filename',
    y_col='category',
    target_size=IMAGE_SIZE,
    class_mode='categorical',
    batch_size=batch_size
)
# Out:
# Found 520 validated image filenames belonging to 2 classes.

# %% [markdown]
# # Create CNN Models

# %% [markdown]
# ## Model 1

# %%
# model 1 hyperparameters
max_neurons = 64
max_dropout = 0.5
optimizer = 'rmsprop'

# %%
model1 = Sequential()

model1.add(Conv2D(max_neurons/4, (3, 3), activation='relu', input_shape=(IMAGE_WIDTH, IMAGE_HEIGHT, IMAGE_CHANNELS)))
model1.add(BatchNormalization())
model1.add(MaxPooling2D(pool_size=(2, 2)))
model1.add(Dropout(max_dropout/2))

model1.add(Conv2D(max_neurons/2, (3, 3), activation='relu'))
model1.add(BatchNormalization())
model1.add(MaxPooling2D(pool_size=(2, 2)))
model1.add(Dropout(max_dropout/2))

model1.add(Conv2D(max_neurons, (3, 3), activation='relu'))
model1.add(BatchNormalization())
model1.add(MaxPooling2D(pool_size=(2, 2)))
model1.add(Dropout(max_dropout/2))

model1.add(Flatten())
model1.add(Dense(max_neurons/2, activation='relu'))
model1.add(BatchNormalization())
model1.add(Dropout(max_dropout))
model1.add(Dense(2, activation='softmax')) # 2 because we have cat and dog classes

model1.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])

model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 126, 126, 16)      448
#
#  batch_normalization (BatchN  (None, 126, 126, 16)     64
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 63, 63, 16)       0
#  )
#
#  dropout (Dropout)           (None, 63, 63, 16)        0
#
#  conv2d_1 (Conv2D)           (None, 61, 61, 32)        4640
#
#  batch_normalization_1 (Batc  (None, 61, 61, 32)       128
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 30, 30, 32)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 30, 30, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 28, 28, 64)        18496
#
#  batch_normalization_2 (Batc  (None, 28, 28, 64)       256
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 14, 14, 64)       0
#  2D)
#
#  dropout_2 (Dropout)         (None, 14, 14, 64)        0
#
#  flatten (Flatten)           (None, 12544)             0
#
#  dense (Dense)               (None, 32)                401440
#
#  batch_normalization_3 (Batc  (None, 32)               128
#  hNormalization)
#
#  dropout_3 (Dropout)         (None, 32)                0
#
#  dense_1 (Dense)             (None, 2)                 66
#
# =================================================================
# Total params: 425,666
# Trainable params: 425,378
# Non-trainable params: 288
# _________________________________________________________________

# %% [markdown]
# ## Model 2

# %%
# model 2 hyperparameters
max_neurons = 128
# max_dropout = 0.4
# optimizer = 'adam'

# %%
model2 = Sequential()

model2.add(Conv2D(max_neurons/4, (3, 3), activation='relu', input_shape=(IMAGE_WIDTH, IMAGE_HEIGHT, IMAGE_CHANNELS)))
model2.add(BatchNormalization())
model2.add(MaxPooling2D(pool_size=(2, 2)))
model2.add(Dropout(max_dropout/2))

model2.add(Conv2D(max_neurons/2, (3, 3), activation='relu'))
model2.add(BatchNormalization())
model2.add(MaxPooling2D(pool_size=(2, 2)))
model2.add(Dropout(max_dropout/2))

model2.add(Conv2D(max_neurons, (3, 3), activation='relu'))
model2.add(BatchNormalization())
model2.add(MaxPooling2D(pool_size=(2, 2)))
model2.add(Dropout(max_dropout/2))

model2.add(Flatten())
model2.add(Dense(max_neurons/2, activation='relu'))
model2.add(BatchNormalization())
model2.add(Dropout(max_dropout))
model2.add(Dense(2, activation='softmax')) # 2 because we have cat and dog classes

model2.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])

model2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 126, 126, 32)      896
#
#  batch_normalization_4 (Batc  (None, 126, 126, 32)     128
#  hNormalization)
#
#  max_pooling2d_3 (MaxPooling  (None, 63, 63, 32)       0
#  2D)
#
#  dropout_4 (Dropout)         (None, 63, 63, 32)        0
#
#  conv2d_4 (Conv2D)           (None, 61, 61, 64)        18496
#
#  batch_normalization_5 (Batc  (None, 61, 61, 64)       256
#  hNormalization)
#
#  max_pooling2d_4 (MaxPooling  (None, 30, 30, 64)       0
#  2D)
#
#  dropout_5 (Dropout)         (None, 30, 30, 64)        0
#
#  conv2d_5 (Conv2D)           (None, 28, 28, 128)       73856
#
#  batch_normalization_6 (Batc  (None, 28, 28, 128)      512
#  hNormalization)
#
#  max_pooling2d_5 (MaxPooling  (None, 14, 14, 128)      0
#  2D)
#
#  dropout_6 (Dropout)         (None, 14, 14, 128)       0
#
#  flatten_1 (Flatten)         (None, 25088)             0
#
#  dense_2 (Dense)             (None, 64)                1605696
#
#  batch_normalization_7 (Batc  (None, 64)               256
#  hNormalization)
#
#  dropout_7 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 2)                 130
#
# =================================================================
# Total params: 1,700,226
# Trainable params: 1,699,650
# Non-trainable params: 576
# _________________________________________________________________

# %% [markdown]
# ##Model 3

# %%
# model 3 hyperparameters
max_neurons = 256
# max_dropout = 0.5
# optimizer = 'SGD'

# %%
model3 = Sequential()

model3.add(Conv2D(max_neurons/4, (3, 3), activation='relu', input_shape=(IMAGE_WIDTH, IMAGE_HEIGHT, IMAGE_CHANNELS)))
model3.add(BatchNormalization())
model3.add(MaxPooling2D(pool_size=(2, 2)))
model3.add(Dropout(max_dropout/2))

model3.add(Conv2D(max_neurons/2, (3, 3), activation='relu'))
model3.add(BatchNormalization())
model3.add(MaxPooling2D(pool_size=(2, 2)))
model3.add(Dropout(max_dropout/2))

model3.add(Conv2D(max_neurons, (3, 3), activation='relu'))
model3.add(BatchNormalization())
model3.add(MaxPooling2D(pool_size=(2, 2)))
model3.add(Dropout(max_dropout/2))

model3.add(Flatten())
model3.add(Dense(max_neurons/2, activation='relu'))
model3.add(BatchNormalization())
model3.add(Dropout(max_dropout))
model3.add(Dense(2, activation='softmax')) # 2 because we have cat and dog classes

model3.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])

model3.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 126, 126, 64)      1792
#
#  batch_normalization_8 (Batc  (None, 126, 126, 64)     256
#  hNormalization)
#
#  max_pooling2d_6 (MaxPooling  (None, 63, 63, 64)       0
#  2D)
#
#  dropout_8 (Dropout)         (None, 63, 63, 64)        0
#
#  conv2d_7 (Conv2D)           (None, 61, 61, 128)       73856
#
#  batch_normalization_9 (Batc  (None, 61, 61, 128)      512
#  hNormalization)
#
#  max_pooling2d_7 (MaxPooling  (None, 30, 30, 128)      0
#  2D)
#
#  dropout_9 (Dropout)         (None, 30, 30, 128)       0
#
#  conv2d_8 (Conv2D)           (None, 28, 28, 256)       295168
#
#  batch_normalization_10 (Bat  (None, 28, 28, 256)      1024
#  chNormalization)
#
#  max_pooling2d_8 (MaxPooling  (None, 14, 14, 256)      0
#  2D)
#
#  dropout_10 (Dropout)        (None, 14, 14, 256)       0
#
#  flatten_2 (Flatten)         (None, 50176)             0
#
#  dense_4 (Dense)             (None, 128)               6422656
#
#  batch_normalization_11 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_11 (Dropout)        (None, 128)               0
#
#  dense_5 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 6,796,034
# Trainable params: 6,794,882
# Non-trainable params: 1,152
# _________________________________________________________________

# %% [markdown]
# #Training/Testing Models

# %% [markdown]
# ## Setting up callbacks

# %%
from keras.callbacks import EarlyStopping, ReduceLROnPlateau

# early stopping callback
earlystop = EarlyStopping(patience=10)

# %%
# reduce the learning rate when the accuracy not increase for 2 steps
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy',
                                            patience=2,
                                            verbose=1,
                                            factor=0.5,
                                            min_lr=0.00001)

# %%
callbacks = [earlystop, learning_rate_reduction]

# %% [markdown]
# ## Model 1

# %%
epochs=10

history = model1.fit(
    train_generator,
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=total_validate//batch_size,
    steps_per_epoch=total_train//batch_size,
    callbacks=callbacks
)
# Out:
# Epoch 1/10
# 138/138 [==============================] - 54s 376ms/step - loss: 0.9028 - accuracy: 0.5797 - val_loss: 2.8422 - val_accuracy: 0.5176 - lr: 0.0010
# Epoch 2/10
# 138/138 [==============================] - 52s 375ms/step - loss: 0.7133 - accuracy: 0.6383 - val_loss: 0.8333 - val_accuracy: 0.4961 - lr: 0.0010
# Epoch 3/10
# 138/138 [==============================] - ETA: 0s - loss: 0.6151 - accuracy: 0.6891
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 138/138 [==============================] - 51s 366ms/step - loss: 0.6151 - accuracy: 0.6891 - val_loss: 1.2736 - val_accuracy: 0.4902 - lr: 0.0010
# Epoch 4/10
# 138/138 [==============================] - 50s 360ms/step - loss: 0.5337 - accuracy: 0.7395 - val_loss: 1.1516 - val_accuracy: 0.5471 - lr: 5.0000e-04
# Epoch 5/10
# 138/138 [==============================] - 51s 369ms/step - loss: 0.4966 - accuracy: 0.7637 - val_loss: 1.0051 - val_accuracy: 0.5824 - lr: 5.0000e-04
# Epoch 6/10
# 138/138 [==============================] - 53s 383ms/step - loss: 0.4557 - accuracy: 0.7923 - val_loss: 0.6692 - val_accuracy: 0.6843 - lr: 5.0000e-04
# Epoch 7/10
# 138/138 [==============================] - 51s 372ms/step - loss: 0.4176 - accuracy: 0.8165 - val_loss: 0.7125 - val_accuracy: 0.6863 - lr: 5.0000e-04
# Epoch 8/10
# 138/138 [==============================] - 54s 392ms/step - loss: 0.4055 - accuracy: 0.8208 - val_loss: 0.8513 - val_accuracy: 0.6529 - lr: 5.0000e-04
# Epoch 9/10
# 138/138 [==============================] - ETA: 0s - loss: 0.3692 - accuracy: 0.8339
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 138/138 [==============================] - 52s 376ms/step - loss: 0.3692 - accuracy: 0.8339 - val_loss: 1.1317 - val_accuracy: 0.6275 - lr: 5.0000e-04
# Epoch 10/10
# 138/138 [==============================] - 51s 367ms/step - loss: 0.3229 - accuracy: 0.8596 - val_loss: 0.7111 - val_accuracy: 0.7275 - lr: 2.5000e-04

# %%
train_score = model1.evaluate_generator(train_generator, verbose=0)
print('Train loss:', train_score[0])
print('Train accuracy', train_score[1])
# Out:
# Train loss: 0.30284905433654785
# Train accuracy 0.8879807591438293

# %%
test_score = model1.evaluate_generator(validation_generator, verbose=0)
print('Test loss:', test_score[0])
print('Test accuracy', test_score[1])
# Out:
# Test loss: 0.7133089303970337
# Test accuracy 0.7250000238418579

# %%
results = pd.DataFrame(columns = ['Model', 'Max Neurons', 'Training Accuracy', 'Testing Accuracy'])

#eval
Model = 'Model 1'
Max_Neurons = 64
Training_Accuracy = train_score[1]
Testing_Accuracy = test_score[1]
row = [Model, Max_Neurons, Training_Accuracy, Testing_Accuracy]
results = results.append(pd.DataFrame([row], columns=results.columns), ignore_index=True)
results
# Out:
#      Model Max Neurons  Training Accuracy  Testing Accuracy
# 0  Model 1          64           0.887981             0.725

# %% [markdown]
# ## Model 2

# %%
epochs=10

history = model2.fit(
    train_generator,
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=total_validate//batch_size,
    steps_per_epoch=total_train//batch_size,
    callbacks=callbacks
)
# Out:
# Epoch 1/10
# 138/138 [==============================] - 98s 696ms/step - loss: 0.9859 - accuracy: 0.5574 - val_loss: 0.9274 - val_accuracy: 0.4902 - lr: 0.0010
# Epoch 2/10
# 138/138 [==============================] - 96s 694ms/step - loss: 0.8003 - accuracy: 0.6044 - val_loss: 2.2920 - val_accuracy: 0.4922 - lr: 0.0010
# Epoch 3/10
# 138/138 [==============================] - 95s 690ms/step - loss: 0.6795 - accuracy: 0.6475 - val_loss: 0.8520 - val_accuracy: 0.5667 - lr: 0.0010
# Epoch 4/10
# 138/138 [==============================] - 96s 695ms/step - loss: 0.5689 - accuracy: 0.7094 - val_loss: 0.9780 - val_accuracy: 0.5569 - lr: 0.0010
# Epoch 5/10
# 138/138 [==============================] - 96s 693ms/step - loss: 0.5121 - accuracy: 0.7404 - val_loss: 0.6510 - val_accuracy: 0.6608 - lr: 0.0010
# Epoch 6/10
# 138/138 [==============================] - 96s 693ms/step - loss: 0.4720 - accuracy: 0.7860 - val_loss: 0.6867 - val_accuracy: 0.6353 - lr: 0.0010
# Epoch 7/10
# 138/138 [==============================] - 96s 695ms/step - loss: 0.4134 - accuracy: 0.8266 - val_loss: 0.5812 - val_accuracy: 0.7196 - lr: 0.0010
# Epoch 8/10
# 138/138 [==============================] - 97s 703ms/step - loss: 0.3740 - accuracy: 0.8397 - val_loss: 0.5977 - val_accuracy: 0.7196 - lr: 0.0010
# Epoch 9/10
# 138/138 [==============================] - ETA: 0s - loss: 0.3301 - accuracy: 0.8639
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 138/138 [==============================] - 98s 708ms/step - loss: 0.3301 - accuracy: 0.8639 - val_loss: 0.7316 - val_accuracy: 0.6804 - lr: 0.0010
# Epoch 10/10
# 138/138 [==============================] - 98s 707ms/step - loss: 0.2648 - accuracy: 0.8935 - val_loss: 0.7315 - val_accuracy: 0.7000 - lr: 5.0000e-04

# %%
train_score = model2.evaluate_generator(train_generator, verbose=0)
print('Train loss:', train_score[0])
print('Train accuracy', train_score[1])
# Out:
# Train loss: 0.23876090347766876
# Train accuracy 0.8942307829856873

# %%
test_score = model2.evaluate_generator(validation_generator, verbose=0)
print('Test loss:', test_score[0])
print('Test accuracy', test_score[1])
# Out:
# Test loss: 0.7334896922111511
# Test accuracy 0.6980769038200378

# %%
#eval
Model = 'Model 2'
Max_Neurons = 128
Training_Accuracy = train_score[1]
Testing_Accuracy = test_score[1]
row = [Model, Max_Neurons, Training_Accuracy, Testing_Accuracy]
results = results.append(pd.DataFrame([row], columns=results.columns), ignore_index=True)
results
# Out:
#      Model Max Neurons  Training Accuracy  Testing Accuracy
# 0  Model 1          64           0.887981          0.725000
# 1  Model 2         128           0.894231          0.698077

# %% [markdown]
# ## Model 3

# %%
epochs=10

history = model3.fit(
    train_generator,
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=total_validate//batch_size,
    steps_per_epoch=total_train//batch_size,
    callbacks=callbacks
)
# Out:
# Epoch 1/10
# 138/138 [==============================] - 247s 2s/step - loss: 1.0461 - accuracy: 0.5850 - val_loss: 0.7671 - val_accuracy: 0.5039 - lr: 0.0010
# Epoch 2/10
# 138/138 [==============================] - 239s 2s/step - loss: 0.7859 - accuracy: 0.6276 - val_loss: 0.7832 - val_accuracy: 0.5235 - lr: 0.0010
# Epoch 3/10
# 138/138 [==============================] - 239s 2s/step - loss: 0.6398 - accuracy: 0.6794 - val_loss: 0.8502 - val_accuracy: 0.5627 - lr: 0.0010
# Epoch 4/10
# 138/138 [==============================] - 239s 2s/step - loss: 0.5510 - accuracy: 0.7346 - val_loss: 0.6776 - val_accuracy: 0.6471 - lr: 0.0010
# Epoch 5/10
# 138/138 [==============================] - 236s 2s/step - loss: 0.4888 - accuracy: 0.7685 - val_loss: 0.6469 - val_accuracy: 0.6490 - lr: 0.0010
# Epoch 6/10
# 138/138 [==============================] - 241s 2s/step - loss: 0.4228 - accuracy: 0.8058 - val_loss: 0.6747 - val_accuracy: 0.6667 - lr: 0.0010
# Epoch 7/10
# 138/138 [==============================] - 241s 2s/step - loss: 0.3573 - accuracy: 0.8465 - val_loss: 0.6201 - val_accuracy: 0.6961 - lr: 0.0010
# Epoch 8/10
# 138/138 [==============================] - 240s 2s/step - loss: 0.3257 - accuracy: 0.8586 - val_loss: 0.8078 - val_accuracy: 0.6725 - lr: 0.0010
# Epoch 9/10
# 138/138 [==============================] - 241s 2s/step - loss: 0.2588 - accuracy: 0.8925 - val_loss: 0.7065 - val_accuracy: 0.7255 - lr: 0.0010
# Epoch 10/10
# 138/138 [==============================] - 239s 2s/step - loss: 0.2169 - accuracy: 0.9109 - val_loss: 0.7443 - val_accuracy: 0.7275 - lr: 0.0010

# %%
train_score = model3.evaluate_generator(train_generator, verbose=0)
print('Train loss:', train_score[0])
print('Train accuracy', train_score[1])
# Out:
# Train loss: 0.1372830867767334
# Train accuracy 0.9427884817123413

# %%
test_score = model3.evaluate_generator(validation_generator, verbose=0)
print('Test loss:', test_score[0])
print('Test accuracy', test_score[1])
# Out:
# Test loss: 0.7556783556938171
# Test accuracy 0.7230769395828247

# %%
#eval
Model = 'Model 3'
Max_Neurons = 256
Training_Accuracy = train_score[1]
Testing_Accuracy = test_score[1]
row = [Model, Max_Neurons, Training_Accuracy, Testing_Accuracy]
results = results.append(pd.DataFrame([row], columns=results.columns), ignore_index=True)
results
# Out:
#      Model Max Neurons  Training Accuracy  Testing Accuracy
# 0  Model 1          64           0.887981          0.725000
# 1  Model 2         128           0.894231          0.698077
# 2  Model 3         256           0.942788          0.723077

# %% [markdown]
# # ROC and Precision/Recall Graphs

# %%
from sklearn.metrics import roc_curve,roc_auc_score, auc

# %%
test_gen = ImageDataGenerator(rescale=1./255)
test_generator = test_gen.flow_from_dataframe(
    validate_df,
    "./train/",
    x_col='filename',
    y_col=None,
    class_mode=None,
    target_size=IMAGE_SIZE,
    batch_size=batch_size,
    shuffle=False
)
# Out:
# Found 520 validated image filenames.

# %% [markdown]
# ## ROC

# %%
y_test = y_test.map({'dog': 1, 'cat': 0}).astype(int)

# %%
y_pred1 = model1.predict_generator(test_generator)
y_pred1 = np.argmax(y_pred1, axis=-1)
y_pred1 = pd.DataFrame(y_pred1, columns = ['category'])
fpr1, tpr1, thresholds1 = roc_curve(y_test, y_pred1)

y_pred2 = model2.predict_generator(test_generator)
y_pred2 = np.argmax(y_pred2, axis=-1)
y_pred2 = pd.DataFrame(y_pred2, columns = ['category'])
fpr2, tpr2, thresholds2 = roc_curve(y_test, y_pred2)

y_pred3 = model3.predict_generator(test_generator)
y_pred3 = np.argmax(y_pred3, axis=-1)
y_pred3 = pd.DataFrame(y_pred3, columns = ['category'])
fpr3, tpr3, thresholds3 = roc_curve(y_test, y_pred3)

# %%
auc1 = auc(fpr1, tpr1)
auc2 = auc(fpr2, tpr2)
auc3 = auc(fpr3, tpr3)

# %%
plt.figure(1)
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr1, tpr1, label='Model 1 (area = {:.3f})'.format(auc1))
plt.plot(fpr2, tpr2, label='Model 2 (area = {:.3f})'.format(auc2))
plt.plot(fpr3, tpr3, label='Model 3 (area = {:.3f})'.format(auc3))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ## Precion Recall

# %%
precision1, recall1, thresholds1 = precision_recall_curve(y_test, y_pred1)
precision2, recall2, thresholds2 = precision_recall_curve(y_test, y_pred2)
precision3, recall3, thresholds3 = precision_recall_curve(y_test, y_pred3)

# %%
plt.figure(1)
plt.plot(recall1, precision1, label='Model 1')
plt.plot(recall2, precision2, label='Model 2')
plt.plot(recall3, precision3, label='Model 3')
plt.title(f'Precision-Recall Curves')
plt.legend(loc='best')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.show()

# %% [markdown]
# #Training the Best Model w/ All Data

# %% [markdown]
# ## Prep Data for Models

# %% [markdown]
# ### Define Constants

# %%
total_train = train_full_df.shape[0]
total_validate = validate_full_df.shape[0]
batch_size=15

IMAGE_WIDTH=128
IMAGE_HEIGHT=128
IMAGE_SIZE=(IMAGE_WIDTH, IMAGE_HEIGHT)
IMAGE_CHANNELS=3

# %%
# model 4 hyperparameters
max_neurons = 64
# max_dropout = 0.5
# optimizer = 'SGD'

# %%
model4 = Sequential()

model4.add(Conv2D(max_neurons/4, (3, 3), activation='relu', input_shape=(IMAGE_WIDTH, IMAGE_HEIGHT, IMAGE_CHANNELS)))
model4.add(BatchNormalization())
model4.add(MaxPooling2D(pool_size=(2, 2)))
model4.add(Dropout(max_dropout/2))

model4.add(Conv2D(max_neurons/2, (3, 3), activation='relu'))
model4.add(BatchNormalization())
model4.add(MaxPooling2D(pool_size=(2, 2)))
model4.add(Dropout(max_dropout/2))

model4.add(Conv2D(max_neurons, (3, 3), activation='relu'))
model4.add(BatchNormalization())
model4.add(MaxPooling2D(pool_size=(2, 2)))
model4.add(Dropout(max_dropout/2))

model4.add(Flatten())
model4.add(Dense(max_neurons/2, activation='relu'))
model4.add(BatchNormalization())
model4.add(Dropout(max_dropout))
model4.add(Dense(2, activation='softmax')) # 2 because we have cat and dog classes

model4.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])

model4.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_9 (Conv2D)           (None, 126, 126, 16)      448
#
#  batch_normalization_12 (Bat  (None, 126, 126, 16)     64
#  chNormalization)
#
#  max_pooling2d_9 (MaxPooling  (None, 63, 63, 16)       0
#  2D)
#
#  dropout_12 (Dropout)        (None, 63, 63, 16)        0
#
#  conv2d_10 (Conv2D)          (None, 61, 61, 32)        4640
#
#  batch_normalization_13 (Bat  (None, 61, 61, 32)       128
#  chNormalization)
#
#  max_pooling2d_10 (MaxPoolin  (None, 30, 30, 32)       0
#  g2D)
#
#  dropout_13 (Dropout)        (None, 30, 30, 32)        0
#
#  conv2d_11 (Conv2D)          (None, 28, 28, 64)        18496
#
#  batch_normalization_14 (Bat  (None, 28, 28, 64)       256
#  chNormalization)
#
#  max_pooling2d_11 (MaxPoolin  (None, 14, 14, 64)       0
#  g2D)
#
#  dropout_14 (Dropout)        (None, 14, 14, 64)        0
#
#  flatten_3 (Flatten)         (None, 12544)             0
#
#  dense_6 (Dense)             (None, 32)                401440
#
#  batch_normalization_15 (Bat  (None, 32)               128
#  chNormalization)
#
#  dropout_15 (Dropout)        (None, 32)                0
#
#  dense_7 (Dense)             (None, 2)                 66
#
# =================================================================
# Total params: 425,666
# Trainable params: 425,378
# Non-trainable params: 288
# _________________________________________________________________

# %% [markdown]
# ### Training Generator

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
)

train_generator_full = train_datagen.flow_from_dataframe(
    train_full_df,
    "./train/",
    x_col='filename',
    y_col='category',
    target_size=IMAGE_SIZE,
    class_mode='categorical',
    batch_size=batch_size
)
# Out:
# Found 20000 validated image filenames belonging to 2 classes.

# %% [markdown]
# ### Validation Generator

# %%
validation_generator_full = validation_datagen.flow_from_dataframe(
    validate_full_df,
    "./train/",
    x_col='filename',
    y_col='category',
    target_size=IMAGE_SIZE,
    class_mode='categorical',
    batch_size=batch_size
)
# Out:
# Found 5000 validated image filenames belonging to 2 classes.

# %% [markdown]
# ##Train/Test the Model

# %%
epochs=3

history = model4.fit(
    train_generator_full,
    epochs=epochs,
    validation_data=validation_generator_full,
    validation_steps=total_validate//batch_size,
    steps_per_epoch=total_train//batch_size,
    callbacks=callbacks
)
# Out:
# Epoch 1/3
# 1333/1333 [==============================] - 515s 386ms/step - loss: 0.5099 - accuracy: 0.7529 - val_loss: 0.5376 - val_accuracy: 0.7449 - lr: 0.0010
# Epoch 2/3
# 1333/1333 [==============================] - 503s 377ms/step - loss: 0.4583 - accuracy: 0.7914 - val_loss: 0.4632 - val_accuracy: 0.7784 - lr: 0.0010
# Epoch 3/3
# 1333/1333 [==============================] - 510s 383ms/step - loss: 0.4238 - accuracy: 0.8100 - val_loss: 0.5042 - val_accuracy: 0.7439 - lr: 0.0010

# %%
test_score_full = model4.evaluate_generator(validation_generator_full, verbose=0)
print('Test loss:', test_score_full[0])
print('Test accuracy', test_score_full[1])
# Out:
# Test loss: 0.504469633102417
# Test accuracy 0.7437999844551086

# %%
y_test_full = y_test_full.map({'dog': 1, 'cat': 0}).astype(int)

# %%
y_pred_full = model4.predict_generator(validation_generator_full)
y_pred_full = np.argmax(y_pred_full, axis=-1)
y_pred_full = pd.DataFrame(y_pred_full, columns = ['category'])
fpr, tpr, thresholds = roc_curve(y_test_full, y_pred_full)

# %%
auc = auc(fpr, tpr)

# %%
plt.figure(1)
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr, tpr, label='Model 1 Final (area = {:.3f})'.format(auc))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc='best')
plt.show()

# %%
precision, recall, thresholds = precision_recall_curve(y_test_full, y_pred_full)

# %%
plt.figure(1)
plt.plot(recall, precision, label='Model 1 Final')
plt.title(f'Precision-Recall Curves')
plt.legend(loc='best')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.show()

# %% [markdown]
# # Predictions for Kaggle

# %% [markdown]
# ## Prep test image data

# %%
# prepare test data
test_filenames = os.listdir("./test/")
test_df = pd.DataFrame({
    'filename': test_filenames
})
nb_samples = len(test_df)

# %%
# create testing image generator
test_gen = ImageDataGenerator(rescale=1./255)
test_generator = test_gen.flow_from_dataframe(
    test_df,
    "./test/",
    x_col='filename',
    y_col=None,
    class_mode=None,
    target_size=IMAGE_SIZE,
    batch_size=1,
    shuffle=False
)
# Out:
# Found 12500 validated image filenames.

# %% [markdown]
# ## Model predictions

# %%
predict = model4.predict_generator(test_generator, steps=nb_samples)

# %% [markdown]
# ## Kaggle Submission

# %%
# For categoral classication the prediction will come with probability of each category. So we will pick the category that have the highest probability with numpy average max
test_df['category'] = np.argmax(predict, axis=-1)

# %%
# convert the predict category back into our generator classes
label_map = dict((v,k) for k,v in train_generator.class_indices.items())
test_df['category'] = test_df['category'].replace(label_map)

# %%
# map the result back to dog is 1 and cat is 0
test_df['category'] = test_df['category'].replace({ 'dog': 1, 'cat': 0 })

# %%
# create Kaggle submission csv
submission_df = test_df.copy()
submission_df['id'] = submission_df['filename'].str.split('.').str[0]
submission_df['label'] = submission_df['category']
submission_df.drop(['filename', 'category'], axis=1, inplace=True)
submission_df.to_csv('submission.csv', index=False)

# %%
files.download('submission.csv')
